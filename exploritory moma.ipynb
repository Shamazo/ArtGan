# %%
import pandas as pd
import numpy as np
import re
import copy 
from urllib.request import urlopen, Request
import urllib
import os
import time
from tqdm import tqdm

# %%
df = pd.read_csv("Artworks.csv")
print(len(df))
# Out:
# 138567

# %%
df.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %%
classes = ['Print', 'Drawing', 'Painting', 'Work on Paper', 'Poster', 'Graphic Design']
df['Classification'].unique()
# Out:
# array(['Architecture', 'Mies van der Rohe Archive', 'Audio', 'Design',
#        'Illustrated Book', 'Print', 'Drawing', 'Periodical', 'Film',
#        'Multiple', 'Photograph', 'Painting', 'Ephemera',
#        'Architectural Model', 'Video', 'Media', 'Performance', 'Software',
#        'Sculpture', 'Installation', 'Product Design',
#        'Photography Research/Reference', 'Work on Paper', 'Poster',
#        '(not assigned)', 'Textile', 'Collage', 'Graphic Design',
#        'Film (object)', 'Frank Lloyd Wright Archive',
#        'Furniture and Interiors'], dtype=object)

# %%
dates = df['Date']
# dates.select_dtypes(include=[str])
# dates[dates.apply(lambda x: isinstance(x, str))]
counter = 0
def convert_date_to_int(date):
    
    try: 
        return int(date)
    except:
        pass
    
    indate = copy.deepcopy(date)
    if pd.isnull(date):
        return np.nan
    
    split_dates = date.split("–")
    split_dates.extend(date.split("-"))
    dates_lst = []
    for dates in split_dates:
        dates_lst.extend(re.findall('\d{4}', date))
      
    try: 
        return int(dates_lst[0])
    except:
        return np.nan
    
df['Date'] = df['Date'].apply(lambda x: convert_date_to_int(x))
print(len(df))
df = df[df['ThumbnailURL'].notnull()]
print(len(df))
df = df[df['Date'] >= 1850]
df = df[df['Date'] <= 2000]
photo =['Photograph']
df = df[df['Classification'].isin(classes)]
df = df[~df['Artist'].isin(['Kirsten Hawthorne'])]
print(len(df))
# Out:
# 138567
# 68905
# 25607

# %%
df["Artist"].iloc[0]
# Out:
# 'Unknown Artist'

# %%
def download_image(url, artist, objectid, out_dir, thumb):
    #commented code is a slightly broken way to get full size 
#     user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"
#     res = urlopen(Request(url, headers={'User-Agent': user_agent }))
#     offset = html.find('class="picture__img--focusable" draggable="false" src="') + len('class="picture__img--focusable" draggable="false" src=" ')
#     offset += html[offset:].find('src=""')
#     end = html[offset:].find("\"")
#     print(offset, end)
#     print(html[offset:])
#     image_url = "https://www.moma.org" + html[offset:offset+end]
    image_name = artist + str(objectid) + ".png"
    try:
        image_path = os.path.join(out_dir, image_name)
    except:
        pass
#     print("image url: ", image_url, "Artwork url: ", url)
    
    if not os.path.exists(image_path):
        
        time.sleep(np.random.random_sample() * 10)
        try:
            image_file = urllib.request.urlretrieve(thumb, image_path)
        except:
            print(thumb)

# %%
df["ThumbnailURL"].iloc[229]
# Out:
# 'http://www.moma.org/media/W1siZiIsIjIwNjI0NiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=6a4756960c27b18c'

# %%
for i in tqdm(range(10000)):
    download_image(df["URL"].iloc[i], df["Artist"].iloc[i], df["ObjectID"].iloc[i], "art_thumbs", df["ThumbnailURL"].iloc[i])
# Out:
#   0%|                                                                                        | 0/10000 [00:00<?, ?it/s]
# http://www.moma.org/media/W1siZiIsIjIwNjI0NiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=6a4756960c27b18c
#   2%|█▊                                                                            | 230/10000 [00:09<06:47, 23.96it/s]
#
#   8%|██████▍                                                                       | 823/10000 [00:17<05:05, 30.07it/s]
#
#   8%|██████▎                                                                     | 826/10000 [00:26<2:19:16,  1.10it/s]
#
#  10%|███████▌                                                                   | 1001/10000 [00:30<1:36:44,  1.55it/s]
#
#  10%|███████▌                                                                   | 1004/10000 [00:47<5:11:29,  2.08s/it]
#
#  10%|███████▌                                                                   | 1005/10000 [00:47<4:01:49,  1.61s/it]
#
# ...
